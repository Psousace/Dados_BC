# %% [markdown]
# <a href="https://colab.research.google.com/github/Psousace/Dados_BC/blob/main/IV_DADOS_IPCA_%26_IGPM_INVESTIR_PRECISO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Investir é Preciso
# ## Link Video: https://www.youtube.com/watch?v=UuBfU11w5qQ&t=62s

# %%
# Instalando Modulos necessários

# !pip install sgs
# !pip install python-bcb
# !pip install --upgrade gspread # usado para manipular google planilhas

from bcb import sgs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Código para conectar no Google Sheets pelo Google Colabt. (no Jupyter código diferente)
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
inflacao = sgs.get({'ipca':433, 'igp-m':189}, start= '2010-01-01')
inflacao
inflacao.plot(kind = 'line', figsize= (12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
inflacao = sgs.get({'IPCA':433, 'IGP-M':189})
inflacao
# Out:
#             IPCA  IGP-M
# Date
# 1980-01-01  6.62    NaN
# 1980-02-01  4.62    NaN
# 1980-03-01  6.04    NaN
# 1980-04-01  5.29    NaN
# 1980-05-01  5.70    NaN
# ...          ...    ...
# 2023-03-01  0.71   0.05
# 2023-04-01  0.61  -0.95
# 2023-05-01  0.23  -1.84
# 2023-06-01 -0.08  -1.93
# 2023-07-01  0.12  -0.72
#
# [523 rows x 2 columns]

# %%
inflacao = sgs.get({'IPCA':13522}, start= '2010-01-01')
inflacao
inflacao.plot(kind = 'line', figsize= (12,4))
# Out:
# <Axes: xlabel='Date'>
