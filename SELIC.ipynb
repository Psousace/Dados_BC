# %% [markdown]
# <a href="https://colab.research.google.com/github/Psousace/Dados_BC/blob/main/SELIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Link Video: https://www.youtube.com/watch?v=mWYv5Q47bzs&t=1291s

# %%
import pandas as pd
import matplotlib.pyplot as plt
# !pip install sgs
# !pip install python-bcb
from bcb import sgs
import numpy as np

# %%
# taxa SELIC META a.a
from bcb import sgs
selic = sgs.get({'Selic':432}, start = '2010-01-01')
# selic

# %%
# prepara e faz grafico das taxas lidas
selic.plot(figsize= (12,4), title= 'Taxa Selic Meta % a.a', fontsize= 10, xlabel= 'Data', ylabel= '% a.a', color='r',tick )
plot.show()

# %%
# prepara e faz grafico das taxas lidas
# serie1 = serie.replace({',':'.'}, regex=True)
# serie1['valor'] = serie1['valor'].astype(float)
# # gera grafico
# serie1.plot.line(x="data",y="valor",title="SELIC taxas ao ano",legend=False)
# # plot.show(block=True)
# plot.figure(figsize=(15,5)).show()
