# %% [markdown]
# <a href="https://colab.research.google.com/github/Psousace/Dados_BC/blob/main/AM_COLETANDO_DADOS_BC_INSERINDO_DATAS_DADOS_SELIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ANALISE MACRO
# ##LINK; https://www.youtube.com/watch?v=7MYWTp_TZNU

# %%
# !pip install python-bcb
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# ...

# %%
from bcb import sgs
selic = sgs.get({'selic':432}, start = '2010-01-01')
selic
# Out:
#             selic
# Date
# 2010-01-01   8.75
# 2010-01-02   8.75
# 2010-01-03   8.75
# 2010-01-04   8.75
# 2010-01-05   8.75
# ...           ...
# 2023-08-20  13.25
# 2023-08-21  13.25
# 2023-08-22  13.25
# 2023-08-23  13.25
# 2023-08-24  13.25
#
# [4984 rows x 1 columns]

# %%
selic.plot(kind = 'line', figsize= (12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
ipca_selic = sgs.get({'ipca':13522, 'selic': 1178}, start= '2021-01-01')
ipca_selic.plot(kind= 'line', figsize=(12,4))

# %%
igpm_month = sgs.get({'ipca':433, 'igpm': 189}, start= '2021-01-01')
igpm_month.plot(kind= 'bar', figsize=(12,4))

# %%
from bcb import Expectativas

# %%
expec = Expectativas()
expec.describe()
# Out:
# EntitySets:
#   ExpectativasMercadoTop5Anuais
#   ExpectativaMercadoMensais
#   ExpectativasMercadoInflacao12Meses
#   ExpectativasMercadoSelic
#   ExpectativasMercadoTop5Selic
#   ExpectativasMercadoTop5Mensais
#   ExpectativasMercadoTrimestrais
#   ExpectativasMercadoAnuais

# %%
expec.describe('ExpectativasMercadoAnuais')
# Out:
# EntitySet (Endpoint): ExpectativasMercadoAnuais
# EntityType: br.gov.bcb.olinda.servico.Expectativas.ExpectativaMercadoAnual
# Properties: Indicador<str>, IndicadorDetalhe<str>, Data<str>, DataReferencia<str>, Media<float>, Mediana<float>, DesvioPadrao<float>, Minimo<float>, Maximo<float>, numeroRespondentes<int>, baseCalculo<int>

# %%
ep = expec.get_endpoint('ExpectativasMercadoAnuais')
ep.query().filter(ep.Indicador == 'Selic').collect()
# Out:
#       Indicador IndicadorDetalhe       Data DataReferencia    Media  Mediana  \
# 0         Selic             None 2000-01-03           2000  16.8300    16.65
# 1         Selic             None 2000-01-04           2000  16.8300    16.65
# 2         Selic             None 2000-01-05           2000  16.8800    16.80
# 3         Selic             None 2000-01-06           2000  16.7300    16.80
# 4         Selic             None 2000-01-07           2000  16.7300    16.80
# ...         ...              ...        ...            ...      ...      ...
# 31647     Selic             None 2023-08-18           2023  11.6769    11.75
# 31648     Selic             None 2023-08-18           2024   9.0185     9.00
# 31649     Selic             None 2023-08-18           2025   8.5381     8.50
# 31650     Selic             None 2023-08-18           2026   8.4800     8.50
# 31651     Selic             None 2023-08-18           2027   8.6375     8.50
#
# ...
