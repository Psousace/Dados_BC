# %% [markdown]
# <a href="https://colab.research.google.com/github/Psousace/Dados_BC/blob/main/IV_DADOS_RF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Link Video: https://www.youtube.com/watch?v=UuBfU11w5qQ&t=62s

# %%
# Instalando Modulos necessários

# !pip install sgs
# !pip install python-bcb

from bcb import sgs
import pandas as pd
import numpy as np
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 85.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 31.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# ...

# %% [markdown]
# #IMA-S
# ###representa a evolução, a preço de mercado, de carteira de titulos publicos remunerados pela SELIC (LFT) (unidade indice, dados diários)

# %%
ima_s = sgs.get({'IMA-S':12462})
ima_s
# Out:
#                   IMA-S
# Date
# 2004-04-30   863.863587
# 2004-05-03   864.119799
# 2004-05-04   864.155113
# 2004-05-05   864.463726
# 2004-05-06   864.844372
# ...                 ...
# 2023-05-16  5915.967189
# 2023-05-17  5918.877590
# 2023-05-18  5921.594365
# 2023-05-19  5924.061747
# 2023-05-22  5926.726013
#
# [4777 rows x 1 columns]

# %%
ima_s.pct_change()
# Out:
#                IMA-S
# Date
# 2004-04-30       NaN
# 2004-05-03  0.000297
# 2004-05-04  0.000041
# 2004-05-05  0.000357
# 2004-05-06  0.000440
# ...              ...
# 2023-05-16  0.000510
# 2023-05-17  0.000492
# 2023-05-18  0.000459
# 2023-05-19  0.000417
# 2023-05-22  0.000450
#
# [4777 rows x 1 columns]

# %% [markdown]
# # IRF-M
# ###Representa a evolução, a preço de mercado, de carteira de titulos publicos prefixados (LTN e NTN-F) (unidade indice, dados diários)

# %%
irf_m = sgs.get({'IRF-M':12461})
irf_m
# Out:
#                    IRF-M
# Date
# 2000-02-01    863.150015
# 2000-02-02    863.786651
# 2000-02-03    864.644959
# 2000-02-04    865.690616
# 2000-02-07    866.529565
# ...                  ...
# 2023-05-16  16379.129480
# 2023-05-17  16368.905445
# 2023-05-18  16387.076635
# 2023-05-19  16387.808492
# 2023-05-22  16391.483608
#
# [5843 rows x 1 columns]

# %% [markdown]
# #IRF-M1
# Representa a evolução, a preço de mercado, de carteira de titulos publicos prefixados (LTN e NTN-F) com prazo inferiores a um ano (unidade indice, dados diários)

# %%
irf_m1 = sgs.get({'IRF-M 1':17626})
irf_m1
# Out:
#                  IRF-M 1
# Date
# 2000-12-01   1000.000000
# 2000-12-04   1000.627565
# 2000-12-05   1002.332823
# 2000-12-06   1003.550214
# 2000-12-07   1004.860026
# ...                  ...
# 2023-05-16  14071.899634
# 2023-05-17  14077.599601
# 2023-05-18  14085.537475
# 2023-05-19  14093.327858
# 2023-05-22  14099.903934
#
# [5634 rows x 1 columns]

# %% [markdown]
# #IRF-M1+
# ###Representa a evolução, a preço de mercado, de carteira de titulos publicos prefixados (LTN e NTN-F) com prazo superiores a um ano (unidade indice, dados diários)

# %%
irf_m_mais = sgs.get({'IRF-M +1':17627})
irf_m_mais
# Out:
#                 IRF-M +1
# Date
# 2000-12-01   1000.000000
# 2000-12-04   1000.584084
# 2000-12-05   1004.253236
# 2000-12-06   1006.851951
# 2000-12-07   1008.910293
# ...                  ...
# 2023-05-16  18058.354177
# 2023-05-17  18035.838293
# 2023-05-18  18061.829424
# 2023-05-19  18057.076807
# 2023-05-22  18058.474834
#
# [5634 rows x 1 columns]

# %% [markdown]
# #IMA-B
# ###Representa a evolução, a preço de mercado, de carteira de titulos publicos indexados ao IPCA (NTN-B) com prazo superiores a um ano (unidade indice, dados diários)

# %%
ima_b = sgs.get({'IMA-B':12466})
ima_ba = ima_b.pct_change()
ima_ba.to_excel('IMA-B.xlsx')
ima_ba
# Out:
#                IMA-B
# Date
# 2004-04-30       NaN
# 2004-05-03  0.000144
# 2004-05-04 -0.000001
# 2004-05-05  0.000024
# 2004-05-06 -0.000290
# ...              ...
# 2023-05-16 -0.002583
# 2023-05-17  0.000039
# 2023-05-18 -0.000873
# 2023-05-19  0.000838
# 2023-05-22 -0.001822
#
# [4777 rows x 1 columns]

# %% [markdown]
# #IMA-B5
# ###Representa a evolução, a preço de mercado, de carteira de titulos publicos indexados ao IPCA (NTN-B) com prazo inferiores a um ano (unidade indice, dados diários)

# %%
ima_b5 = sgs.get({'IMA-B 5':12467})
ima_b5
# Out:
#                 IMA-B 5
# Date
# 2004-04-30   889.937050
# 2004-05-03   890.099266
# 2004-05-04   889.756377
# 2004-05-05   890.361815
# 2004-05-06   890.553037
# ...                 ...
# 2023-05-16  8485.095256
# 2023-05-17  8470.520162
# 2023-05-18  8462.198306
# 2023-05-19  8460.316574
# 2023-05-22  8452.892231
#
# [4777 rows x 1 columns]

# %% [markdown]
# #IMA-B5+
# ###Representa a evolução, a preço de mercado, de carteira de titulos publicos indexados ao IPCA (NTN-B) com prazo superiores a um ano (unidade indice, dados diários)

# %%
ima_b5_mais = sgs.get({'IMA-B 5':12468})
ima_b5_mais
# Out:
#                  IMA-B 5
# Date
# 2004-04-30    893.092656
# 2004-05-03    893.214228
# 2004-05-04    893.279337
# 2004-05-05    893.187806
# 2004-05-06    892.842008
# ...                  ...
# 2023-05-16  10670.786923
# 2023-05-17  10684.385469
# 2023-05-18  10675.878007
# 2023-05-19  10692.750086
# 2023-05-22  10666.205208
#
# [4777 rows x 1 columns]

# %% [markdown]
# #IMA-Geral
# ###Representa a evolução, a preço de mercado, de carteira de titulos publicos federais(unidade indice, dados diários)

# %%
ima_geral = sgs.get({'IMA-Geral':12469})
ima_geral
# Out:
#               IMA-Geral
# Date
# 2004-04-30   867.287469
# 2004-05-03   867.354821
# 2004-05-04   867.451874
# 2004-05-05   867.890903
# 2004-05-06   868.097448
# ...                 ...
# 2023-05-16  7346.393894
# 2023-05-17  7345.550380
# 2023-05-18  7347.270904
# 2023-05-19  7350.207870
# 2023-05-22  7347.910854
#
# [4777 rows x 1 columns]

# %%
display(ima_s, irf_m, irf_m1, irf_m_mais, ima_b, ima_b5, ima_b5_mais, ima_geral)
# Out:
#                   IMA-S
# Date
# 2004-04-30   863.863587
# 2004-05-03   864.119799
# 2004-05-04   864.155113
# 2004-05-05   864.463726
# 2004-05-06   864.844372
# ...                 ...
# 2023-05-16  5915.967189
# 2023-05-17  5918.877590
# 2023-05-18  5921.594365
# 2023-05-19  5924.061747
# 2023-05-22  5926.726013
#
# [4777 rows x 1 columns]
#                    IRF-M
# Date
# 2000-02-01    863.150015
# 2000-02-02    863.786651
# 2000-02-03    864.644959
# 2000-02-04    865.690616
# 2000-02-07    866.529565
# ...                  ...
# 2023-05-16  16379.129480
# 2023-05-17  16368.905445
# 2023-05-18  16387.076635
# 2023-05-19  16387.808492
# 2023-05-22  16391.483608
#
# [5843 rows x 1 columns]
#                  IRF-M 1
# Date
# 2000-12-01   1000.000000
# 2000-12-04   1000.627565
# 2000-12-05   1002.332823
# 2000-12-06   1003.550214
# 2000-12-07   1004.860026
# ...                  ...
# 2023-05-16  14071.899634
# 2023-05-17  14077.599601
# 2023-05-18  14085.537475
# ...

# %%
tabela = pd.DataFrame()
lista = 'ima_s irf_m irf_m1 irf_m_mais ima_b ima_b5 ima_b5_mais ima_geral'.split()
lista
# Out:
# ['ima_s',
#  'irf_m',
#  'irf_m1',
#  'irf_m_mais',
#  'ima_b',
#  'ima_b5',
#  'ima_b5_mais',
#  'ima_geral']
