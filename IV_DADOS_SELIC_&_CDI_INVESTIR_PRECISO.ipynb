# %% [markdown]
# <a href="https://colab.research.google.com/github/Psousace/Dados_BC/blob/main/IV_DADOS_SELIC_%26_CDI_INVESTIR_PRECISO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INVESTIR É PRECISO
# ## Link Video: https://www.youtube.com/watch?v=UuBfU11w5qQ&t=62s

# %%
# Instalando Modulos necessários

# !pip install sgs
# !pip install python-bcb
# !pip install --upgrade gspread # usado para manipular google planilhas

from bcb import sgs
import pandas as pd
import numpy as np


# Código para conectar no Google Sheets pelo Google Colabt. (no Jupyter código diferente)
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 1.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: gspread
# ...

# %%
Taxa_Selic_Meta_aa = sgs.get({'selic':432}, start='2010-01-01')
Taxa_Selic_Meta_aa
# Out:
#             selic
# Date
# 2010-01-01   8.75
# 2010-01-02   8.75
# 2010-01-03   8.75
# 2010-01-04   8.75
# 2010-01-05   8.75
# ...           ...
# 2023-08-20  13.25
# 2023-08-21  13.25
# 2023-08-22  13.25
# 2023-08-23  13.25
# 2023-08-24  13.25
#
# [4984 rows x 1 columns]

# %%
Taxa_Selic_Meta_aa.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
Taxa_Selic_Meta_aa = sgs.get({'Taxa Selic Meta':432})
Taxa_Selic_Meta_aa
# Out:
#             Taxa Selic Meta
# Date
# 1999-03-05            45.00
# 1999-03-06            45.00
# 1999-03-07            45.00
# 1999-03-08            45.00
# 1999-03-09            45.00
# ...                     ...
# 2023-09-16            13.25
# 2023-09-17            13.25
# 2023-09-18            13.25
# 2023-09-19            13.25
# 2023-09-20            13.25
#
# [8966 rows x 1 columns]

# %%
Taxa_Selic_Meta_aa.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
Taxa_Selic_diaria = sgs.get({'SELIC Diaria':11})
Taxa_Selic_diaria
# Out:
#             SELIC Diaria
# Date
# 1986-06-04      0.065041
# 1986-06-05      0.067397
# 1986-06-06      0.066740
# 1986-06-09      0.068247
# 1986-06-10      0.067041
# ...                  ...
# 2023-08-17      0.049037
# 2023-08-18      0.049037
# 2023-08-21      0.049037
# 2023-08-22      0.049037
# 2023-08-23      0.049037
#
# [9331 rows x 1 columns]

# %%
selic_Anualizada = sgs.get({'SELIC Anualiada 252':1178})
selic_Anualizada
# Out:
#             SELIC Anualiada 252
# Date
# 1986-06-04                17.80
# 1986-06-05                18.50
# 1986-06-06                18.31
# 1986-06-09                18.76
# 1986-06-10                18.40
# ...                         ...
# 2023-08-17                13.15
# 2023-08-18                13.15
# 2023-08-21                13.15
# 2023-08-22                13.15
# 2023-08-23                13.15
#
# [9331 rows x 1 columns]

# %%
selic_Anualizada = sgs.get({'SELIC Anualiada 252':1178}, start='2010-01-01')
selic_Anualizada
# Out:
#             SELIC Anualiada 252
# Date
# 2009-12-31                 8.65
# 2010-01-04                 8.65
# 2010-01-05                 8.65
# 2010-01-06                 8.65
# 2010-01-07                 8.65
# ...                         ...
# 2023-08-17                13.15
# 2023-08-18                13.15
# 2023-08-21                13.15
# 2023-08-22                13.15
# 2023-08-23                13.15
#
# [3428 rows x 1 columns]

# %%
cdi_diario = sgs.get({'CDI Diario':12})
cdi_diario
# Out:
#             CDI Diario
# Date
# 1986-03-06    0.068111
# 1986-03-10    0.069028
# 1986-03-12    0.067417
# 1986-03-14    0.064584
# 1986-03-17    0.068222
# ...                ...
# 2023-08-16    0.049037
# 2023-08-17    0.049037
# 2023-08-18    0.049037
# 2023-08-21    0.049037
# 2023-08-22    0.049037
#
# [9372 rows x 1 columns]

# %%
cdi_anualizado = sgs.get({'CDI Anualizado':4389})
cdi_anualizado
# Out:
#             CDI Anualizado
# Date
# 1986-03-06           18.72
# 1986-03-10           18.99
# 1986-03-12           18.51
# 1986-03-14           17.67
# 1986-03-17           18.75
# ...                    ...
# 2023-08-16           13.15
# 2023-08-17           13.15
# 2023-08-18           13.15
# 2023-08-21           13.15
# 2023-08-22           13.15
#
# [9372 rows x 1 columns]

# %%
cdi_acum_mes = sgs.get({'CDI Acum Mes':4391})
cdi_acum_mes
# Out:
#             CDI Acum Mes
# Date
# 1986-03-01          0.87
# 1986-04-01          1.37
# 1986-05-01          1.32
# 1986-06-01          1.57
# 1986-07-01          2.23
# ...                  ...
# 2023-04-01          0.92
# 2023-05-01          1.12
# 2023-06-01          1.07
# 2023-07-01          1.07
# 2023-08-01          0.79
#
# [450 rows x 1 columns]

# %%
cdi_acum_anual = sgs.get({'CDI Acum Anual':4392})
cdi_acum_anual
# Out:
#             CDI Acum Anual
# Date
# 1986-03-01           18.24
# 1986-04-01           17.75
# 1986-05-01           17.98
# 1986-06-01           20.51
# 1986-07-01           27.27
# ...                    ...
# 2023-04-01           13.65
# 2023-05-01           13.65
# 2023-06-01           13.65
# 2023-07-01           13.65
# 2023-08-01           13.21
#
# [450 rows x 1 columns]

# %%
selic = sgs.get({'Taxa_Selic_Meta_aa':432, 'selic_Anualizada': 4389}, start= '2000-01-01')
selic.plot(kind= 'line', figsize=(12,4))
selic
# Out:
#             Taxa_Selic_Meta_aa  selic_Anualizada
# Date
# 1999-12-31                 NaN             18.83
# 2000-01-01               19.00               NaN
# 2000-01-02               19.00               NaN
# 2000-01-03               19.00             18.78
# 2000-01-04               19.00             18.75
# ...                        ...               ...
# 2023-08-20               13.25               NaN
# 2023-08-21               13.25             13.15
# 2023-08-22               13.25             13.15
# 2023-08-23               13.25               NaN
# 2023-08-24               13.25               NaN
#
# [8638 rows x 2 columns]
